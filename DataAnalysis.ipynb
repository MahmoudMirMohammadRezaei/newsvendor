# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("D:/MahmooDev/DataSet Thesis/modedColumns.csv")
# df = df.loc[df['PROD_CODE'] == 'PRD0900005']

# take a look at the dataset
df.head()
# Out:
#    SHOP_WEEK  SHOP_DATE  SHOP_WEEKDAY  SHOP_HOUR  QUANTITY  SPEND   PROD_CODE  \
# 0     200607   20060410             2         13         1   1.25  PRD0901663
# 1     200607   20060413             5         19         1   1.25  PRD0901663
# 2     200607   20060413             5         17         1   0.97  PRD0901665
# 3     200607   20060414             6         12         1   0.97  PRD0901665
# 4     200607   20060412             4         13         1   1.32  PRD0901666
#
#   PROD_CODE_10 PROD_CODE_20 PROD_CODE_30  ... CUST_LIFESTAGE        BASKET_ID  \
# 0      CL00111     DEP00039       G00010  ...            NaN  994100100183427
# 1      CL00111     DEP00039       G00010  ...             OT  994100100470238
# 2      CL00102     DEP00034       G00010  ...            NaN  994100100196859
# 3      CL00102     DEP00034       G00010  ...            NaN  994100100701620
# 4      CL00131     DEP00047       G00013  ...            NaN  994100100385811
#
# ...

# %%
cdf = df[['SHOP_WEEK','SHOP_WEEKDAY','SHOP_HOUR','QUANTITY','SPEND','BASKET_SIZE','BASKET_DOMINANT_MISSION',"PROD_CODE","SHOP_WEEK_DAY_HOUR"]]
cdf.head(9)
# Out:
#    SHOP_WEEK  SHOP_WEEKDAY  SHOP_HOUR  QUANTITY  SPEND BASKET_SIZE  \
# 0     200607             2         13         1   1.25           L
# 1     200607             5         19         1   1.25           M
# 2     200607             5         17         1   0.97           L
# 3     200607             6         12         1   0.97           L
# 4     200607             4         13         1   1.32           L
# 5     200607             4         14         1   1.32           L
# 6     200607             1         21         1   0.53           M
# 7     200607             7         18         1   0.53           L
# 8     200607             5         17         1   0.53           M
#
#   BASKET_DOMINANT_MISSION   PROD_CODE  SHOP_WEEK_DAY_HOUR
# 0                   Mixed  PRD0901663         20060410213
# 1                   Mixed  PRD0901663         20060413519
# 2                   Mixed  PRD0901665         20060413517
# 3                   Fresh  PRD0901665         20060414612
# ...

# %%
plt.scatter(cdf.SHOP_WEEKDAY, cdf.QUANTITY,  color='blue')
plt.xlabel("SHOP_WEEK_DAY_HOUR")
plt.ylabel("QUANTITY")
plt.show()
